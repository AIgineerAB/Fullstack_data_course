# %% [markdown]
# # Exploring olympic games dataset
#
#
# Dataset found here
# - [Olympics 124 years Dataset(till 2020)](https://www.kaggle.com/datasets/nitishsharma01/olympics-124-years-datasettill-2020)

# %%
import pandas as pd 

df_summer = pd.read_csv("../data/athletes_summer_games.csv", index_col=0)
df_summer
# Out:
#                                      Name Sex   Age            Team  NOC  \
# 0                               A Dijiang   M  24.0           China  CHN
# 1                                A Lamusi   M  23.0           China  CHN
# 2                     Gunnar Nielsen Aaby   M  24.0         Denmark  DEN
# 3                    Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN
# 26     Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands  NED
# ...                                   ...  ..   ...             ...  ...
# 15116                   ZWOLINSKA Klaudia   F  22.0          Poland  POL
# 15117                        ZYKOVA Yulia   F  25.0          Russia  ROC
# 15118                   ZYUZINA Ekaterina   F  24.0          Russia  ROC
# 15119                     ZYZANSKA Sylwia   F  24.0          Poland  POL
# 15120                     ZYZANSKA Sylwia   F  24.0          Poland  POL
#
#              Games  Year  Season         City         Sport  \
# ...

# %%
df_swe = df_summer.query("NOC == 'SWE'")

df_swe_medals = df_swe[df_swe["Medal"].notna()]
df_swe_medals
# Out:
#                                  Name Sex   Age    Team  NOC        Games  \
# 727                   Nils Georg berg   M  19.0  Sweden  SWE  1912 Summer
# 728                   Nils Georg berg   M  19.0  Sweden  SWE  1912 Summer
# 903                    Ara Abrahamian   M  29.0  Sweden  SWE  2004 Summer
# 929     Erik Adolf Efraim Abrahamsson   M  22.0  Sweden  SWE  1920 Summer
# 1237   Fausto Alesio Acke (Padovini-)   M  22.0  Sweden  SWE  1920 Summer
# ...                               ...  ..   ...     ...  ...          ...
# 11835                  SCHOUGH Olivia   F  30.0  Sweden  SWE  2020 Summer
# 11946                  SEGER Caroline   F  36.0  Sweden  SWE  2020 Summer
# 12308                SJOESTROEM Sarah   F  27.0  Sweden  SWE  2020 Summer
# 12569                    STAHL Daniel   M  28.0  Sweden  SWE  2020 Summer
# 14016            von ECKERMANN Henrik   M  40.0  Sweden  SWE  2020 Summer
#
#        Year  Season       City       Sport  \
# ...

# %%
df_summer[df_summer["Medal"].notna()].groupby("NOC")["Medal"].count().sort_values(
    ascending=False
)
# Out:
# NOC
# USA    5300
# GBR    2126
# URS    2063
# GER    1860
# FRA    1768
#        ...
# BUR       1
# TOG       1
# TKM       1
# CYP       1
# ERI       1
# Name: Medal, Length: 151, dtype: int64

# %%
total_medals_swe = len(df_swe_medals)
total_medals_swe
# Out:
# 1142

# %%
df_swe_medals.groupby("Name")["Medal"].count().sort_values(ascending=False)
# Out:
# Name
# Alfred Gomer Albert "Alf" Swahn    9
# Gert Fridolf Fredriksson           8
# Gustaf Vilhelm Carlberg            8
# Eric Otto Valdemar Lemming         7
# Agneta Monica Andersson            7
#                                   ..
# Gunnar Alf Erik Berggren           1
# Gunnar Alfred Olsson               1
# Gunnar Anton Edvard Asther         1
# Gunnar Emil Gabrielsson            1
# von ECKERMANN Henrik               1
# Name: Medal, Length: 830, dtype: int64

# %%
df_summer[df_summer["Medal"].notna()]
# Out:
#                           Name Sex   Age            Team  NOC        Games  \
# 3         Edgar Lindenau Aabye   M  34.0  Denmark/Sweden  DEN  1900 Summer
# 37        Arvo Ossian Aaltonen   M  30.0         Finland  FIN  1920 Summer
# 38        Arvo Ossian Aaltonen   M  30.0         Finland  FIN  1920 Summer
# 41     Paavo Johannes Aaltonen   M  28.0         Finland  FIN  1948 Summer
# 42     Paavo Johannes Aaltonen   M  28.0         Finland  FIN  1948 Summer
# ...                        ...  ..   ...             ...  ...          ...
# 15102             ZOU Jingyuan   M  23.0           China  CHN  2020 Summer
# 15105         ZUBIMENDI Martin   M  22.0           Spain  ESP  2020 Summer
# 15106           ZUEV Alexander   M  24.0          Russia  ROC  2020 Summer
# 15112         ZVEREV Alexander   M  24.0         Germany  GER  2020 Summer
# 15117             ZYKOVA Yulia   F  25.0          Russia  ROC  2020 Summer
#
#        Year  Season       City                Sport  \
# ...
